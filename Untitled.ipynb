# %% [markdown]
# # 1/ Vẽ bản đồ vào file

# %%
with open('maze_map_no_bonus1.txt', 'w') as outfile:
  outfile.write('0\n')
  outfile.write('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx\n')
  outfile.write('x                               xxxxxxxx  x\n')
  outfile.write('x                               x      x  x\n')
  outfile.write('x                               x   x  x  x\n')
  outfile.write('x                               x   x  x  x\n')
  outfile.write('x                               x   x  x  x\n')
  outfile.write('x                               x   x  x  x\n')
  outfile.write('x                               x   x  x  x\n')
  outfile.write('x                               x   x  x  x\n')
  outfile.write('x      xxxxxxxxxxxxxxxxxxxxxxxxxx   x     x\n')
  outfile.write('x      S                            x      \n')
  outfile.write('x      x   xxxxxxxxxxxxxxxxxxxxxxxxxx     x\n')
  outfile.write('x                                         x\n')
  outfile.write('x      xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx\n')
  outfile.write('x                                         x\n')
  outfile.write('x                                         x\n')
  outfile.write('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx\n')

# %%
with open('maze_map_no_bonus2.txt', 'w') as outfile:
  outfile.write('0\n')
  outfile.write('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx\n')
  outfile.write('x                                         x\n')
  outfile.write('x                                     xx  x\n')
  outfile.write('x             xxxx x  xxxxx   xxxxxxxx    x\n')
  outfile.write('x                   x                     x\n')
  outfile.write('x          xxx                            x\n')
  outfile.write('x       xxx            xxxx   xxxxxx      x\n')
  outfile.write('x       xxx                               x\n')
  outfile.write('x  x x  x             S                   x\n')
  outfile.write('x   x   x    xxxxxxxxxx                   x\n')
  outfile.write('x   x  xxxxxxxxx   xxxxxxxxxxxxxxx        x\n')
  outfile.write('        x                        xxxxx    x\n')
  outfile.write('x       x               x x  x        x   x\n')
  outfile.write('x                      x               x  x\n')
  outfile.write('x        xxxxxxxxxxxx x       x           x\n')
  outfile.write('x        xx            x xxxxxx           x\n')
  outfile.write('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx\n')

# %%
with open('maze_map_no_bonus3.txt', 'w') as outfile:
  outfile.write('0\n')
  outfile.write('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx\n')
  outfile.write('xxxx         xx       x xxxx                            x\n')
  outfile.write('x  xx  xx       xxxxx        xxxxxxxxxxxxxx             x\n')
  outfile.write('x  xxx    xxxxxx           xx              x            x\n')
  outfile.write('x               xxxxxx    xx             xxx            x\n')
  outfile.write('x                 xxxxx   xx             x  xxx         x\n')
  outfile.write('x      xx    x      x   xx                  xxx         x\n')
  outfile.write('x     x                 xxxx               xx           x\n')
  outfile.write('x      xx    x        xxx  x               xxx          x\n')
  outfile.write('x       x    x       xxx    xx           xxx            x\n')
  outfile.write('x       x    x        xxxxx             xxx             x\n')
  outfile.write('x       x    x       xxxxx             xxx              x\n')
  outfile.write('x            x                            xxxx          x\n')
  outfile.write('x            xxxx       xxxxxxxx           xxx          x\n')
  outfile.write('x            Sx                xx xxxx   xxxxxxxx       x\n')
  outfile.write('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx      xxxxx xxxxx\n')
  outfile.write('x                                                       x\n')
  outfile.write('                                                        x\n')
  outfile.write('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx\n')

# %%
with open('maze_map_no_bonus4.txt', 'w') as outfile:
  outfile.write('0\n')
  outfile.write('xxxxxxxxxxxxxxxxxxxx\n')
  outfile.write('xxxxxxxxxxxxxx x   x\n')
  outfile.write('x                  x\n')
  outfile.write('x  x xxxxxxxxx x   x\n')
  outfile.write('x  x x       x     x\n')
  outfile.write('x  x xxxxxxxxx xx  x\n')
  outfile.write('x S              x x\n')
  outfile.write('xx xxxxxxxxxx xxx  x\n')
  outfile.write('xx            x    x\n')
  outfile.write('xxxxxxxxxxxxxxx     \n')
  outfile.write('xxxxxxxxxxxxxxxxxxxx\n')

# %%
with open('maze_map_no_bonus5.txt', 'w') as outfile:
  outfile.write('0\n')
  outfile.write('xxxxxxxxxxxxxxxxxxxx\n')
  outfile.write('xx         x       x\n')
  outfile.write('xxx   xxx    x x   x\n')
  outfile.write('xx   x   x x    xx x\n')
  outfile.write('xx       x x     x x\n')
  outfile.write('xx    x  x     x x x\n')
  outfile.write('xx       x x     x x\n')
  outfile.write('x       xx x        \n')
  outfile.write('x xxxxxxxx xxxxxxxxx\n')
  outfile.write('xS                 x\n')
  outfile.write('xxxxxxxxxxxxxxxxxxxx\n')

# %%
with open('maze_map_with_bonus.txt', 'w') as outfile:
  outfile.write('2\n')
  outfile.write('3 6 -3\n')
  outfile.write('5 14 -1\n')
  outfile.write('xxxxxxxxxxxxxxxxxxxxxx\n')
  outfile.write('x   x   xx xx        x\n')
  outfile.write('x     x     xxxxxxxxxx\n')
  outfile.write('x x   +xx  xxxx xxx xx\n')
  outfile.write('  x   x x xx   xxxx  x\n')
  outfile.write('x          xx +xx  x x\n')
  outfile.write('xxxxxxx x      xx  x x\n')
  outfile.write('xxxxxxxxx  x x  xx   x\n')
  outfile.write('x          x x Sx x  x\n')
  outfile.write('xxxxx x  x x x     x x\n')
  outfile.write('xxxxxxxxxxxxxxxxxxxxxx')

# %%
def read_file(file_name: str = 'maze.txt'):
  f=open(file_name,'r')
  n_bonus_points = int(next(f)[:-1])
  bonus_points = []
  for i in range(n_bonus_points):
    x, y, reward = map(int, next(f)[:-1].split(' '))
    bonus_points.append([x, y, reward])

  text=f.read()
  matrix=[list(i) for i in text.splitlines()]
  f.close()

  return bonus_points, matrix

# %% [markdown]
# # 2/ Xử lí hình vẽ mê cung

# %%
import os
import matplotlib.pyplot as plt
from queue import PriorityQueue
import math
import copy

# %%
def visualize_maze(matrix,bonus, start,end, route=None):
    """
    Args:
      1. matrix: The matrix read from the input file,
      2. bonus: The array of bonus points,
      3. start, end: The starting and ending points,
      4. route: The route from the starting point to the ending one, defined by an array of (x, y), e.g. route = [(1, 2), (1, 3), (1, 4)]
    """
    #1. Define walls and array of direction based on the route
    walls=[(i,j) for i in range(len(matrix)) for j in range(len(matrix[0])) if matrix[i][j]=='x']

    if route:
        direction=[]
        for i in range(1,len(route)):
            if route[i][0]-route[i-1][0]>0:
                direction.append('v') #^
            elif route[i][0]-route[i-1][0]<0:
                direction.append('^') #v        
            elif route[i][1]-route[i-1][1]>0:
                direction.append('>')
            else:
                direction.append('<')

        direction.pop(0)

    #2. Drawing the map
    ax=plt.figure(dpi=100).add_subplot(111)

    for i in ['top','bottom','right','left']:
        ax.spines[i].set_visible(False)

    plt.scatter([i[1] for i in walls],[-i[0] for i in walls],
                marker='X',s=100,color='black')
    
    plt.scatter([i[1] for i in bonus],[-i[0] for i in bonus],
                marker='P',s=100,color='green')
    plt.scatter(start[1],-start[0],marker='*',
                s=100,color='gold')

    if route:
        for i in range(len(route)-2):
            plt.scatter(route[i+1][1],-route[i+1][0],
                        marker=direction[i],color='silver')

    plt.text(end[1],-end[0],'EXIT',color='red',
         horizontalalignment='center',
         verticalalignment='center')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# %% [markdown]
# # I/ BẢN ĐỒ KHÔNG ĐIỂM THƯỞNG

# %%
def adj(matrix, u):
    result = []
    try:
        if matrix[u[0]-1][u[1]] != 'x':
            result.append([u[0]-1,u[1]])
    except: 
        pass
    try:
        if matrix[u[0]][u[1]-1] != 'x':
            result.append([u[0],u[1]-1])
    except: 
        pass
    try:
        if matrix[u[0]+1][u[1]] != 'x':
            result.append([u[0]+1,u[1]])
    except: 
        pass
    try:
        if matrix[u[0]][u[1]+1] != 'x':
            result.append([u[0],u[1]+1])
    except: 
        pass
    return result

# %%
def dfs(node, visited = [], path = []): 
    if node not in visited and end not in visited: 
        visited.append(node)
        path.append(node)
        for u in adj(matrix, node):
            dfs(u, visited, path) 
        if end not in path: 
            path.pop()
        else:
            return path

# %%
def bfs(start, end):
    path = []
    path_queue = []
    path_queue.append([start])
    visited = []
    k = 1
    while k and path_queue != []:
        path = path_queue.pop(0)
        x = path[-1]
        for u in adj(matrix, x):
            if u not in visited:
                visited.append(u)
                if u == end: 
                    k = 0
                    break
                path_temp = copy.copy(path)
                path_temp.append(u)
                path_queue.append(path_temp)
    path.append(end)
    return path

# %%
def Heuristic(u, end):
    return math.sqrt(abs(u[0]-end[0])+abs(u[1]-end[1]))
def greedy_best_first_search(start, end):
    visited = []
    path_queue = PriorityQueue()
    path_queue.put((0, [start]))
    while path_queue.empty() == False:
        path = path_queue.get()[1] #get list path
        u = path[-1] #last node in the path
        if u == end:
            return path
        for x in adj(matrix, u):
            if x not in visited:
                path_temp = copy.copy(path)
                visited.append(x)
                path_temp.append(x)
                path_queue.put((Heuristic(x,end), path_temp))
    return path

# %%
def Heuristic(u, end):
    return math.sqrt((u[0]-end[0])**2+(u[1]-end[1])**2)

#Ham g(n) chính là hàm len(path): Chiều dài của một path 
# Tuong Tu Nhu Greedy Search nhung them vao do la ham len(path) == g(n)  ham h(n) la mahattan
def A_asterisk(start, end):
    visited = []
    path_queue = PriorityQueue()
    path_queue.put((0, [start]))
    while path_queue.empty() == False:
        path = path_queue.get()[1] #get list path
        u = path[-1] #last node in the path
        if u == end:
            return path
        for x in adj(matrix, u):
            if x not in visited:
                path_temp = copy.copy(path)
                visited.append(x)
                path_temp.append(x)
                f= len(path_temp) + Heuristic(x,end)
                path_queue.put((f,  path_temp))
    return path

# %%
    
for index in range(1,6):
    bonus_points, matrix = read_file(f'maze_map_no_bonus{index}.txt')
    # Find Start and End corodinate 
    end = [0,0]
    for i in range(len(matrix)):
        for j in range(len(matrix[0])):
            if matrix[i][j]=='S':
                start=[i,j]
            elif matrix[i][j]==' ':
                if (i==0) or (i==len(matrix)-1) or (j==0) or (j==len(matrix[0])-1):
                    end=[i,j]

            else:
                pass
    visited = []
    path = []
    print('------------------------------------------------------------------------------------')
    print(f'matrix{i}X{j}')
    print(f"Ma trận Không có điểm thưởng thứ {index}")
    print('Depth-First_Search')
    visualize_maze(matrix, bonus_points, start,end, dfs(start, visited, path))
    print('Breadth First Search')
    visualize_maze(matrix, bonus_points, start,end, bfs(start,end))
    print('greedy_best_first_search')
    visualize_maze(matrix, bonus_points, start,end, greedy_best_first_search(start,end))
    print('A_Star_Search')
    visualize_maze(matrix, bonus_points, start,end, A_asterisk(start,end))
# Out:
# ------------------------------------------------------------------------------------
# matrix16X42
# Ma trận Không có điểm thưởng thứ 1
# Depth-First_Search
# Breadth First Search
# greedy_best_first_search
# A_Star_Search
# ------------------------------------------------------------------------------------
# matrix16X42
# Ma trận Không có điểm thưởng thứ 2
# Depth-First_Search
# Breadth First Search
# greedy_best_first_search
# A_Star_Search
# ------------------------------------------------------------------------------------
# matrix18X56
# Ma trận Không có điểm thưởng thứ 3
# Depth-First_Search
# Breadth First Search
# greedy_best_first_search
# A_Star_Search
# ------------------------------------------------------------------------------------
# matrix10X19
# Ma trận Không có điểm thưởng thứ 4
# Depth-First_Search
# Breadth First Search
# greedy_best_first_search
# A_Star_Search
# ------------------------------------------------------------------------------------
# ...

# %%
bonus_points, matrix = read_file(f'maze_map_with_bonus.txt') 
print(bonus_points)
# Out:
# [[3, 6, -3], [5, 14, -1]]

# %%
# Out:
#   File "C:\Users\ASUS\AppData\Local\Temp/ipykernel_23352/1310187009.py", line 12
#     f = len(path_temp)+ Heuristic(x,end) -
#                                            ^
# SyntaxError: invalid syntax

# %%
adj(matrix, [1,1])
